# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# * @file NLP基礎/NLP_part5.ipynb
#   * @brief NLP基礎 模型實作
#
#   * 此份程式碼是以教學為目的，附有完整的架構解說。
#
#   * @author 人工智慧科技基金會 AI 工程師 - 康文瑋
#   * Email: run963741@aif.tw
#   * Resume: https://www.cakeresume.com/run963741
#
#   * 最後更新日期: 2020/11/26

# %% [markdown]
# # 載入套件

# %%
import pandas as pd
import xgboost as xgb
import pickle
import numpy as np
import os

from gensim.models import word2vec

os.chdir('/content/drive/Shared drives/類技術班教材/標準版/NLP基礎')

# %% [markdown]
# # 特徵前處理
#
# 我們前面已經透過許多特徵擷取的方法來萃取文本特徵，接下來，我們比較前一個章節 (NLP_part4) 所產生的特徵之間的分類表現，分別有：
#
# * Continuous bag of words (CBOW)
# * Skip-gram

# %%
htl_count_feature = pd.read_csv('Data/htl_simple_count_feature.csv')

# %%
with open('Data/htl_cutted.pickle', 'rb') as f:
  data = pickle.load(f)

# %%
data[0]
# Out:
# ['距離',
#  '川沙',
#  '公路',
#  '較',
#  '近',
#  ',',
#  '但是',
#  '公交',
#  '指示',
#  '不',
#  '對',
#  ',',
#  '如果',
#  '是',
#  '"',
#  '蔡陸線',
#  '"',
#  '的話',
#  ',',
#  '會',
#  '非常',
#  '麻煩',
#  '.',
#  '建議',
#  '用',
#  '別的',
#  '路線',
#  '.',
#  '房間',
#  '較',
#  '爲',
#  '簡單',
#  '.']

# %% [markdown]
# ## Continuous bag of words (CBOW)
#
# 這邊會做一個比較特別的前處理，因為大部分的模型都是輸入一筆資料並得到一個預測值，資料通常是一個向量，但是當把句子中所有詞都轉成詞向量之後，整個句子就變成矩陣，也就沒辦法丟進模型裡面，所以這邊將句子中所有詞向量做平均，就形成一個句向量。

# %%
# 載入 cbow 模型
cbow_model = word2vec.Word2Vec.load("word2vec_model/cbow.model")
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:252: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
# 過濾不在 vocabulary 裡面的詞
data_filtered = [[w for w in l if w in cbow_model.wv] for l in data]

# 將句子中的每個詞向量加起來做平均，變成句向量
cbow_avg_vector = []

for l in data_filtered:
    if len(l)==0: # 句子中可能有所有詞全部都不曾出現在 vocabulary 中，假設為 0
        cbow_avg_vector.append(np.array([0]*128))
    else: # 將每個詞都轉成詞向量，然後平均
        sent_embed = np.mean([cbow_model.wv[w] for w in l], axis=0)
        cbow_avg_vector.append(sent_embed)

# %%
cbow_avg_vector = np.array(cbow_avg_vector)

# %%
# 共有 7765 個句子，每個句子的句向量為 128 維
cbow_avg_vector.shape
# Out:
# (7765, 128)

# %% [markdown]
# ## Skip-gram

# %%
# 載入 skip-gram 模型
skipgram_model = word2vec.Word2Vec.load("word2vec_model/skipgram.model")
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:252: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
# 過濾不在 vocabulary 裡面的詞
data_filtered = [[w for w in l if w in skipgram_model.wv] for l in data]

# 將句子中的每個詞向量加起來做平均，變成句向量
skipgram_avg_vector = []

for l in data_filtered:
    if len(l)==0: # 句子中skipgram_avg_vector可能有所有詞全部都不曾出現在 vocabulary 中，假設為 0
        skipgram_avg_vector.append(np.array([0]*128))
    else: # 將每個詞都轉成詞向量，然後平均
        sent_embed = np.mean([skipgram_model.wv[w] for w in l], axis=0)
        skipgram_avg_vector.append(sent_embed)

# %%
skipgram_avg_vector = np.array(skipgram_avg_vector)

# %%
# 共有 7765 個句子，每個句子的句向量為 128 維
skipgram_avg_vector.shape
# Out:
# (7765, 128)

# %% [markdown]
# # 訓練模型

# %% [markdown]
# ## Train test split
#
# 切割訓練集以及測試集

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# %%
train, test = train_test_split(htl_count_feature, test_size=0.2, stratify=htl_count_feature['label'])
train_idx = np.array(train.index)
test_idx = np.array(test.index)

# %%
print('Training size: ', train_idx.shape)
print('Testing size: ', test_idx.shape)
# Out:
# Training size:  (6212,)
# Testing size:  (1553,)

# %%
def train_model_pipeline(data):
  model = xgb.XGBClassifier(n_estimators=500)
  model.fit(data[train_idx,:], htl_count_feature['label'][train_idx], 
          eval_set=[(data[test_idx, :], htl_count_feature['label'][test_idx])])
  y_pred = model.predict(data[test_idx, :])

  report = classification_report(y_true=htl_count_feature['label'][test_idx], y_pred=y_pred)
  cnfm = confusion_matrix(y_true=htl_count_feature['label'][test_idx], y_pred=y_pred)
  cnfm = pd.DataFrame(cnfm, columns=['Pred_0','Pred_1'], index=['Actual_0','Actual_1'])

  return y_pred, report, cnfm

# %% [markdown]
# ## CBOW

# %%
cbow_y_pred, cbow_report, cbow_cnfm = train_model_pipeline(cbow_avg_vector)
# Out:
# [0]	validation_0-error:0.238892
# [1]	validation_0-error:0.207985
# [2]	validation_0-error:0.198326
# [3]	validation_0-error:0.195106
# [4]	validation_0-error:0.189311
# [5]	validation_0-error:0.186735
# [6]	validation_0-error:0.183516
# [7]	validation_0-error:0.18094
# [8]	validation_0-error:0.179652
# [9]	validation_0-error:0.186091
# [10]	validation_0-error:0.186735
# [11]	validation_0-error:0.182872
# [12]	validation_0-error:0.181584
# [13]	validation_0-error:0.181584
# [14]	validation_0-error:0.175789
# [15]	validation_0-error:0.172569
# [16]	validation_0-error:0.173857
# [17]	validation_0-error:0.174501
# [18]	validation_0-error:0.167418
# [19]	validation_0-error:0.171281
# [20]	validation_0-error:0.168706
# [21]	validation_0-error:0.16613
# [22]	validation_0-error:0.166774
# [23]	validation_0-error:0.164198
# [24]	validation_0-error:0.164842
# [25]	validation_0-error:0.161623
# [26]	validation_0-error:0.163554
# [27]	validation_0-error:0.160335
# [28]	validation_0-error:0.161623
# [29]	validation_0-error:0.160979
# [30]	validation_0-error:0.159691
# [31]	validation_0-error:0.159047
# [32]	validation_0-error:0.159691
# [33]	validation_0-error:0.162267
# [34]	validation_0-error:0.160335
# [35]	validation_0-error:0.157115
# [36]	validation_0-error:0.151964
# [37]	validation_0-error:0.155184
# [38]	validation_0-error:0.153896
# [39]	validation_0-error:0.153252
# [40]	validation_0-error:0.15454
# [41]	validation_0-error:0.15132
# [42]	validation_0-error:0.150032
# [43]	validation_0-error:0.150676
# [44]	validation_0-error:0.152608
# [45]	validation_0-error:0.150032
# [46]	validation_0-error:0.151964
# [47]	validation_0-error:0.150032
# [48]	validation_0-error:0.15132
# [49]	validation_0-error:0.150032
# [50]	validation_0-error:0.151964
# [51]	validation_0-error:0.152608
# [52]	validation_0-error:0.153896
# [53]	validation_0-error:0.153896
# [54]	validation_0-error:0.152608
# [55]	validation_0-error:0.15132
# [56]	validation_0-error:0.148744
# [57]	validation_0-error:0.1481
# [58]	validation_0-error:0.149388
# [59]	validation_0-error:0.1481
# [60]	validation_0-error:0.147457
# [61]	validation_0-error:0.147457
# [62]	validation_0-error:0.144237
# [63]	validation_0-error:0.145525
# [64]	validation_0-error:0.145525
# [65]	validation_0-error:0.146813
# [66]	validation_0-error:0.145525
# [67]	validation_0-error:0.144881
# [68]	validation_0-error:0.143593
# [69]	validation_0-error:0.144237
# [70]	validation_0-error:0.142949
# [71]	validation_0-error:0.142949
# [72]	validation_0-error:0.143593
# [73]	validation_0-error:0.144237
# [74]	validation_0-error:0.144237
# [75]	validation_0-error:0.142305
# [76]	validation_0-error:0.141017
# [77]	validation_0-error:0.141661
# [78]	validation_0-error:0.139086
# [79]	validation_0-error:0.141017
# [80]	validation_0-error:0.142949
# [81]	validation_0-error:0.140373
# [82]	validation_0-error:0.137798
# [83]	validation_0-error:0.137798
# [84]	validation_0-error:0.13651
# [85]	validation_0-error:0.13973
# [86]	validation_0-error:0.137154
# [87]	validation_0-error:0.141661
# [88]	validation_0-error:0.141017
# [89]	validation_0-error:0.139086
# [90]	validation_0-error:0.141661
# [91]	validation_0-error:0.141017
# [92]	validation_0-error:0.142305
# [93]	validation_0-error:0.142305
# [94]	validation_0-error:0.142305
# [95]	validation_0-error:0.144237
# [96]	validation_0-error:0.143593
# [97]	validation_0-error:0.143593
# [98]	validation_0-error:0.142949
# [99]	validation_0-error:0.145525
# [100]	validation_0-error:0.145525
# [101]	validation_0-error:0.145525
# [102]	validation_0-error:0.144881
# [103]	validation_0-error:0.142949
# [104]	validation_0-error:0.142949
# [105]	validation_0-error:0.144881
# [106]	validation_0-error:0.142949
# [107]	validation_0-error:0.144881
# [108]	validation_0-error:0.144881
# [109]	validation_0-error:0.143593
# [110]	validation_0-error:0.141661
# [111]	validation_0-error:0.141661
# [112]	validation_0-error:0.142949
# [113]	validation_0-error:0.141661
# [114]	validation_0-error:0.141017
# [115]	validation_0-error:0.13973
# [116]	validation_0-error:0.141017
# [117]	validation_0-error:0.140373
# [118]	validation_0-error:0.141017
# [119]	validation_0-error:0.140373
# [120]	validation_0-error:0.140373
# [121]	validation_0-error:0.141661
# [122]	validation_0-error:0.141661
# [123]	validation_0-error:0.142949
# [124]	validation_0-error:0.142305
# [125]	validation_0-error:0.141017
# [126]	validation_0-error:0.141017
# [127]	validation_0-error:0.142949
# [128]	validation_0-error:0.142305
# [129]	validation_0-error:0.141661
# [130]	validation_0-error:0.141661
# [131]	validation_0-error:0.143593
# [132]	validation_0-error:0.142949
# [133]	validation_0-error:0.143593
# [134]	validation_0-error:0.143593
# [135]	validation_0-error:0.143593
# [136]	validation_0-error:0.144881
# [137]	validation_0-error:0.145525
# [138]	validation_0-error:0.144237
# [139]	validation_0-error:0.142305
# [140]	validation_0-error:0.142305
# [141]	validation_0-error:0.142949
# [142]	validation_0-error:0.143593
# [143]	validation_0-error:0.144237
# [144]	validation_0-error:0.144237
# [145]	validation_0-error:0.144237
# [146]	validation_0-error:0.144237
# [147]	validation_0-error:0.144881
# [148]	validation_0-error:0.142305
# [149]	validation_0-error:0.142949
# [150]	validation_0-error:0.142949
# [151]	validation_0-error:0.143593
# [152]	validation_0-error:0.142949
# [153]	validation_0-error:0.144237
# [154]	validation_0-error:0.143593
# [155]	validation_0-error:0.144237
# [156]	validation_0-error:0.141661
# [157]	validation_0-error:0.142949
# [158]	validation_0-error:0.142949
# [159]	validation_0-error:0.142949
# [160]	validation_0-error:0.141017
# [161]	validation_0-error:0.142305
# [162]	validation_0-error:0.142305
# [163]	validation_0-error:0.142949
# [164]	validation_0-error:0.142305
# [165]	validation_0-error:0.142305
# [166]	validation_0-error:0.141017
# [167]	validation_0-error:0.141017
# [168]	validation_0-error:0.141017
# [169]	validation_0-error:0.141661
# [170]	validation_0-error:0.140373
# [171]	validation_0-error:0.141017
# [172]	validation_0-error:0.143593
# [173]	validation_0-error:0.142305
# [174]	validation_0-error:0.141661
# [175]	validation_0-error:0.141017
# [176]	validation_0-error:0.141017
# [177]	validation_0-error:0.141017
# [178]	validation_0-error:0.140373
# [179]	validation_0-error:0.13973
# [180]	validation_0-error:0.13973
# [181]	validation_0-error:0.140373
# [182]	validation_0-error:0.139086
# [183]	validation_0-error:0.139086
# [184]	validation_0-error:0.139086
# [185]	validation_0-error:0.13973
# [186]	validation_0-error:0.139086
# [187]	validation_0-error:0.140373
# [188]	validation_0-error:0.138442
# [189]	validation_0-error:0.139086
# [190]	validation_0-error:0.139086
# [191]	validation_0-error:0.141017
# [192]	validation_0-error:0.141661
# [193]	validation_0-error:0.141017
# [194]	validation_0-error:0.141661
# [195]	validation_0-error:0.143593
# [196]	validation_0-error:0.142949
# [197]	validation_0-error:0.142305
# [198]	validation_0-error:0.142949
# [199]	validation_0-error:0.142305
# [200]	validation_0-error:0.140373
# [201]	validation_0-error:0.140373
# [202]	validation_0-error:0.141017
# [203]	validation_0-error:0.141661
# [204]	validation_0-error:0.141017
# [205]	validation_0-error:0.140373
# [206]	validation_0-error:0.140373
# [207]	validation_0-error:0.140373
# [208]	validation_0-error:0.13973
# [209]	validation_0-error:0.141017
# [210]	validation_0-error:0.140373
# [211]	validation_0-error:0.140373
# [212]	validation_0-error:0.141017
# [213]	validation_0-error:0.141017
# [214]	validation_0-error:0.140373
# [215]	validation_0-error:0.142305
# [216]	validation_0-error:0.141017
# [217]	validation_0-error:0.140373
# [218]	validation_0-error:0.139086
# [219]	validation_0-error:0.13973
# [220]	validation_0-error:0.142949
# [221]	validation_0-error:0.142305
# [222]	validation_0-error:0.142305
# [223]	validation_0-error:0.141661
# [224]	validation_0-error:0.13973
# [225]	validation_0-error:0.13973
# [226]	validation_0-error:0.141017
# [227]	validation_0-error:0.141017
# [228]	validation_0-error:0.140373
# [229]	validation_0-error:0.142305
# [230]	validation_0-error:0.140373
# [231]	validation_0-error:0.141017
# [232]	validation_0-error:0.141017
# [233]	validation_0-error:0.13973
# [234]	validation_0-error:0.13973
# [235]	validation_0-error:0.139086
# [236]	validation_0-error:0.137154
# [237]	validation_0-error:0.137154
# [238]	validation_0-error:0.137798
# [239]	validation_0-error:0.13651
# [240]	validation_0-error:0.134578
# [241]	validation_0-error:0.135866
# [242]	validation_0-error:0.134578
# [243]	validation_0-error:0.134578
# [244]	validation_0-error:0.134578
# [245]	validation_0-error:0.13651
# [246]	validation_0-error:0.137154
# [247]	validation_0-error:0.137154
# [248]	validation_0-error:0.13651
# [249]	validation_0-error:0.135866
# [250]	validation_0-error:0.135866
# [251]	validation_0-error:0.135866
# [252]	validation_0-error:0.135866
# [253]	validation_0-error:0.137154
# [254]	validation_0-error:0.138442
# [255]	validation_0-error:0.137798
# [256]	validation_0-error:0.137154
# [257]	validation_0-error:0.138442
# [258]	validation_0-error:0.13651
# [259]	validation_0-error:0.13651
# [260]	validation_0-error:0.13651
# [261]	validation_0-error:0.137798
# [262]	validation_0-error:0.137154
# [263]	validation_0-error:0.13651
# [264]	validation_0-error:0.137154
# [265]	validation_0-error:0.137154
# [266]	validation_0-error:0.137154
# [267]	validation_0-error:0.13651
# [268]	validation_0-error:0.135866
# [269]	validation_0-error:0.135866
# [270]	validation_0-error:0.135866
# [271]	validation_0-error:0.135866
# [272]	validation_0-error:0.13651
# [273]	validation_0-error:0.135866
# [274]	validation_0-error:0.139086
# [275]	validation_0-error:0.138442
# [276]	validation_0-error:0.138442
# [277]	validation_0-error:0.139086
# [278]	validation_0-error:0.138442
# [279]	validation_0-error:0.139086
# [280]	validation_0-error:0.138442
# [281]	validation_0-error:0.138442
# [282]	validation_0-error:0.137798
# [283]	validation_0-error:0.137798
# [284]	validation_0-error:0.137798
# [285]	validation_0-error:0.138442
# [286]	validation_0-error:0.139086
# [287]	validation_0-error:0.139086
# [288]	validation_0-error:0.13973
# [289]	validation_0-error:0.138442
# [290]	validation_0-error:0.137798
# [291]	validation_0-error:0.139086
# [292]	validation_0-error:0.138442
# [293]	validation_0-error:0.138442
# [294]	validation_0-error:0.13973
# [295]	validation_0-error:0.139086
# [296]	validation_0-error:0.139086
# [297]	validation_0-error:0.139086
# [298]	validation_0-error:0.137154
# [299]	validation_0-error:0.137154
# [300]	validation_0-error:0.137154
# [301]	validation_0-error:0.13651
# [302]	validation_0-error:0.137154
# [303]	validation_0-error:0.137798
# [304]	validation_0-error:0.13973
# [305]	validation_0-error:0.139086
# [306]	validation_0-error:0.13973
# [307]	validation_0-error:0.13973
# [308]	validation_0-error:0.13973
# [309]	validation_0-error:0.138442
# [310]	validation_0-error:0.138442
# [311]	validation_0-error:0.13973
# [312]	validation_0-error:0.13973
# [313]	validation_0-error:0.141017
# [314]	validation_0-error:0.140373
# [315]	validation_0-error:0.139086
# [316]	validation_0-error:0.13973
# [317]	validation_0-error:0.138442
# [318]	validation_0-error:0.137798
# [319]	validation_0-error:0.139086
# [320]	validation_0-error:0.137798
# [321]	validation_0-error:0.137798
# [322]	validation_0-error:0.138442
# [323]	validation_0-error:0.138442
# [324]	validation_0-error:0.137798
# [325]	validation_0-error:0.137798
# [326]	validation_0-error:0.138442
# [327]	validation_0-error:0.137798
# [328]	validation_0-error:0.137798
# [329]	validation_0-error:0.137798
# [330]	validation_0-error:0.139086
# [331]	validation_0-error:0.139086
# [332]	validation_0-error:0.137798
# [333]	validation_0-error:0.13651
# [334]	validation_0-error:0.13651
# [335]	validation_0-error:0.13651
# [336]	validation_0-error:0.137154
# [337]	validation_0-error:0.13651
# [338]	validation_0-error:0.137154
# [339]	validation_0-error:0.13651
# [340]	validation_0-error:0.135866
# [341]	validation_0-error:0.13651
# [342]	validation_0-error:0.135866
# [343]	validation_0-error:0.135866
# [344]	validation_0-error:0.135866
# [345]	validation_0-error:0.135222
# [346]	validation_0-error:0.13651
# [347]	validation_0-error:0.135866
# [348]	validation_0-error:0.135866
# [349]	validation_0-error:0.135222
# [350]	validation_0-error:0.134578
# [351]	validation_0-error:0.135222
# [352]	validation_0-error:0.135866
# [353]	validation_0-error:0.135222
# [354]	validation_0-error:0.135222
# [355]	validation_0-error:0.135866
# [356]	validation_0-error:0.135866
# [357]	validation_0-error:0.134578
# [358]	validation_0-error:0.133934
# [359]	validation_0-error:0.133934
# [360]	validation_0-error:0.134578
# [361]	validation_0-error:0.133934
# [362]	validation_0-error:0.135866
# [363]	validation_0-error:0.135866
# [364]	validation_0-error:0.13651
# [365]	validation_0-error:0.13651
# [366]	validation_0-error:0.137154
# [367]	validation_0-error:0.137798
# [368]	validation_0-error:0.137154
# [369]	validation_0-error:0.137154
# [370]	validation_0-error:0.137798
# [371]	validation_0-error:0.139086
# [372]	validation_0-error:0.139086
# [373]	validation_0-error:0.139086
# [374]	validation_0-error:0.139086
# [375]	validation_0-error:0.137798
# [376]	validation_0-error:0.138442
# [377]	validation_0-error:0.139086
# [378]	validation_0-error:0.139086
# [379]	validation_0-error:0.13973
# [380]	validation_0-error:0.139086
# [381]	validation_0-error:0.138442
# [382]	validation_0-error:0.13651
# [383]	validation_0-error:0.139086
# [384]	validation_0-error:0.139086
# [385]	validation_0-error:0.137798
# [386]	validation_0-error:0.137798
# [387]	validation_0-error:0.137154
# [388]	validation_0-error:0.137154
# [389]	validation_0-error:0.137798
# [390]	validation_0-error:0.137798
# [391]	validation_0-error:0.137154
# [392]	validation_0-error:0.137798
# [393]	validation_0-error:0.139086
# [394]	validation_0-error:0.138442
# [395]	validation_0-error:0.138442
# [396]	validation_0-error:0.13651
# [397]	validation_0-error:0.137798
# [398]	validation_0-error:0.137798
# [399]	validation_0-error:0.138442
# [400]	validation_0-error:0.137798
# [401]	validation_0-error:0.137154
# [402]	validation_0-error:0.138442
# [403]	validation_0-error:0.13973
# [404]	validation_0-error:0.13973
# [405]	validation_0-error:0.139086
# [406]	validation_0-error:0.140373
# [407]	validation_0-error:0.139086
# [408]	validation_0-error:0.137154
# [409]	validation_0-error:0.137154
# [410]	validation_0-error:0.138442
# [411]	validation_0-error:0.139086
# [412]	validation_0-error:0.138442
# [413]	validation_0-error:0.139086
# [414]	validation_0-error:0.137798
# [415]	validation_0-error:0.140373
# [416]	validation_0-error:0.140373
# [417]	validation_0-error:0.140373
# [418]	validation_0-error:0.13973
# [419]	validation_0-error:0.139086
# [420]	validation_0-error:0.13973
# [421]	validation_0-error:0.13973
# [422]	validation_0-error:0.13973
# [423]	validation_0-error:0.139086
# [424]	validation_0-error:0.138442
# [425]	validation_0-error:0.137798
# [426]	validation_0-error:0.137154
# [427]	validation_0-error:0.139086
# [428]	validation_0-error:0.13973
# [429]	validation_0-error:0.13973
# [430]	validation_0-error:0.13973
# [431]	validation_0-error:0.138442
# [432]	validation_0-error:0.13973
# [433]	validation_0-error:0.13973
# [434]	validation_0-error:0.139086
# [435]	validation_0-error:0.138442
# [436]	validation_0-error:0.13973
# [437]	validation_0-error:0.139086
# [438]	validation_0-error:0.139086
# [439]	validation_0-error:0.139086
# [440]	validation_0-error:0.139086
# [441]	validation_0-error:0.141017
# [442]	validation_0-error:0.140373
# [443]	validation_0-error:0.13973
# [444]	validation_0-error:0.140373
# [445]	validation_0-error:0.13973
# [446]	validation_0-error:0.141661
# [447]	validation_0-error:0.13973
# [448]	validation_0-error:0.140373
# [449]	validation_0-error:0.140373
# [450]	validation_0-error:0.141017
# [451]	validation_0-error:0.141017
# [452]	validation_0-error:0.142305
# [453]	validation_0-error:0.141017
# [454]	validation_0-error:0.141017
# [455]	validation_0-error:0.140373
# [456]	validation_0-error:0.141017
# [457]	validation_0-error:0.140373
# [458]	validation_0-error:0.13973
# [459]	validation_0-error:0.13973
# [460]	validation_0-error:0.139086
# [461]	validation_0-error:0.139086
# [462]	validation_0-error:0.139086
# [463]	validation_0-error:0.139086
# [464]	validation_0-error:0.139086
# [465]	validation_0-error:0.139086
# [466]	validation_0-error:0.138442
# [467]	validation_0-error:0.138442
# [468]	validation_0-error:0.138442
# [469]	validation_0-error:0.139086
# [470]	validation_0-error:0.139086
# [471]	validation_0-error:0.138442
# [472]	validation_0-error:0.139086
# [473]	validation_0-error:0.140373
# [474]	validation_0-error:0.140373
# [475]	validation_0-error:0.141017
# [476]	validation_0-error:0.141017
# [477]	validation_0-error:0.140373
# [478]	validation_0-error:0.13973
# [479]	validation_0-error:0.13973
# [480]	validation_0-error:0.13973
# [481]	validation_0-error:0.13973
# [482]	validation_0-error:0.13973
# [483]	validation_0-error:0.141017
# [484]	validation_0-error:0.140373
# [485]	validation_0-error:0.141661
# [486]	validation_0-error:0.142305
# [487]	validation_0-error:0.142305
# [488]	validation_0-error:0.143593
# [489]	validation_0-error:0.142305
# [490]	validation_0-error:0.141661
# [491]	validation_0-error:0.141661
# [492]	validation_0-error:0.140373
# [493]	validation_0-error:0.141017
# [494]	validation_0-error:0.139086
# [495]	validation_0-error:0.13973
# [496]	validation_0-error:0.140373
# [497]	validation_0-error:0.139086
# [498]	validation_0-error:0.140373
# [499]	validation_0-error:0.141017

# %% [markdown]
# ## Skip-gram

# %%
skipgram_y_pred, skipgram_report, skipgram_cnfm = train_model_pipeline(skipgram_avg_vector)
# Out:
# [0]	validation_0-error:0.226658
# [1]	validation_0-error:0.232453
# [2]	validation_0-error:0.203477
# [3]	validation_0-error:0.207341
# [4]	validation_0-error:0.207985
# [5]	validation_0-error:0.200258
# [6]	validation_0-error:0.193818
# [7]	validation_0-error:0.194462
# [8]	validation_0-error:0.200258
# [9]	validation_0-error:0.197038
# [10]	validation_0-error:0.196394
# [11]	validation_0-error:0.197038
# [12]	validation_0-error:0.193818
# [13]	validation_0-error:0.187379
# [14]	validation_0-error:0.184804
# [15]	validation_0-error:0.183516
# [16]	validation_0-error:0.183516
# [17]	validation_0-error:0.182872
# [18]	validation_0-error:0.185448
# [19]	validation_0-error:0.18094
# [20]	validation_0-error:0.177077
# [21]	validation_0-error:0.177077
# [22]	validation_0-error:0.175789
# [23]	validation_0-error:0.173213
# [24]	validation_0-error:0.173857
# [25]	validation_0-error:0.171925
# [26]	validation_0-error:0.167418
# [27]	validation_0-error:0.166774
# [28]	validation_0-error:0.16613
# [29]	validation_0-error:0.166774
# [30]	validation_0-error:0.167418
# [31]	validation_0-error:0.16613
# [32]	validation_0-error:0.167418
# [33]	validation_0-error:0.164842
# [34]	validation_0-error:0.16613
# [35]	validation_0-error:0.166774
# [36]	validation_0-error:0.162267
# [37]	validation_0-error:0.163554
# [38]	validation_0-error:0.162267
# [39]	validation_0-error:0.163554
# [40]	validation_0-error:0.164198
# [41]	validation_0-error:0.160335
# [42]	validation_0-error:0.160335
# [43]	validation_0-error:0.157759
# [44]	validation_0-error:0.160335
# [45]	validation_0-error:0.160335
# [46]	validation_0-error:0.158403
# [47]	validation_0-error:0.157115
# [48]	validation_0-error:0.160335
# [49]	validation_0-error:0.159047
# [50]	validation_0-error:0.157115
# [51]	validation_0-error:0.157115
# [52]	validation_0-error:0.156471
# [53]	validation_0-error:0.15454
# [54]	validation_0-error:0.153896
# [55]	validation_0-error:0.153896
# [56]	validation_0-error:0.152608
# [57]	validation_0-error:0.153896
# [58]	validation_0-error:0.152608
# [59]	validation_0-error:0.15132
# [60]	validation_0-error:0.152608
# [61]	validation_0-error:0.152608
# [62]	validation_0-error:0.15132
# [63]	validation_0-error:0.150032
# [64]	validation_0-error:0.150032
# [65]	validation_0-error:0.149388
# [66]	validation_0-error:0.1481
# [67]	validation_0-error:0.148744
# [68]	validation_0-error:0.146813
# [69]	validation_0-error:0.149388
# [70]	validation_0-error:0.146813
# [71]	validation_0-error:0.146813
# [72]	validation_0-error:0.147457
# [73]	validation_0-error:0.146169
# [74]	validation_0-error:0.145525
# [75]	validation_0-error:0.145525
# [76]	validation_0-error:0.146169
# [77]	validation_0-error:0.144881
# [78]	validation_0-error:0.142305
# [79]	validation_0-error:0.142949
# [80]	validation_0-error:0.13973
# [81]	validation_0-error:0.140373
# [82]	validation_0-error:0.140373
# [83]	validation_0-error:0.13973
# [84]	validation_0-error:0.13973
# [85]	validation_0-error:0.13973
# [86]	validation_0-error:0.138442
# [87]	validation_0-error:0.13973
# [88]	validation_0-error:0.139086
# [89]	validation_0-error:0.137154
# [90]	validation_0-error:0.139086
# [91]	validation_0-error:0.138442
# [92]	validation_0-error:0.139086
# [93]	validation_0-error:0.13973
# [94]	validation_0-error:0.139086
# [95]	validation_0-error:0.139086
# [96]	validation_0-error:0.13973
# [97]	validation_0-error:0.139086
# [98]	validation_0-error:0.137798
# [99]	validation_0-error:0.138442
# [100]	validation_0-error:0.139086
# [101]	validation_0-error:0.138442
# [102]	validation_0-error:0.13651
# [103]	validation_0-error:0.135222
# [104]	validation_0-error:0.135866
# [105]	validation_0-error:0.135222
# [106]	validation_0-error:0.135866
# [107]	validation_0-error:0.135222
# [108]	validation_0-error:0.134578
# [109]	validation_0-error:0.133934
# [110]	validation_0-error:0.133934
# [111]	validation_0-error:0.133934
# [112]	validation_0-error:0.134578
# [113]	validation_0-error:0.134578
# [114]	validation_0-error:0.13329
# [115]	validation_0-error:0.132646
# [116]	validation_0-error:0.132003
# [117]	validation_0-error:0.132646
# [118]	validation_0-error:0.132003
# [119]	validation_0-error:0.133934
# [120]	validation_0-error:0.132646
# [121]	validation_0-error:0.13329
# [122]	validation_0-error:0.132646
# [123]	validation_0-error:0.132646
# [124]	validation_0-error:0.13329
# [125]	validation_0-error:0.133934
# [126]	validation_0-error:0.133934
# [127]	validation_0-error:0.134578
# [128]	validation_0-error:0.134578
# [129]	validation_0-error:0.13329
# [130]	validation_0-error:0.133934
# [131]	validation_0-error:0.135222
# [132]	validation_0-error:0.134578
# [133]	validation_0-error:0.135222
# [134]	validation_0-error:0.13651
# [135]	validation_0-error:0.135222
# [136]	validation_0-error:0.135866
# [137]	validation_0-error:0.135222
# [138]	validation_0-error:0.135222
# [139]	validation_0-error:0.133934
# [140]	validation_0-error:0.133934
# [141]	validation_0-error:0.132646
# [142]	validation_0-error:0.132646
# [143]	validation_0-error:0.133934
# [144]	validation_0-error:0.13329
# [145]	validation_0-error:0.134578
# [146]	validation_0-error:0.133934
# [147]	validation_0-error:0.134578
# [148]	validation_0-error:0.134578
# [149]	validation_0-error:0.135222
# [150]	validation_0-error:0.13329
# [151]	validation_0-error:0.133934
# [152]	validation_0-error:0.135222
# [153]	validation_0-error:0.135222
# [154]	validation_0-error:0.134578
# [155]	validation_0-error:0.13329
# [156]	validation_0-error:0.132646
# [157]	validation_0-error:0.13329
# [158]	validation_0-error:0.130071
# [159]	validation_0-error:0.131359
# [160]	validation_0-error:0.130071
# [161]	validation_0-error:0.130715
# [162]	validation_0-error:0.130715
# [163]	validation_0-error:0.130071
# [164]	validation_0-error:0.130071
# [165]	validation_0-error:0.128139
# [166]	validation_0-error:0.128139
# [167]	validation_0-error:0.128139
# [168]	validation_0-error:0.128783
# [169]	validation_0-error:0.129427
# [170]	validation_0-error:0.128783
# [171]	validation_0-error:0.129427
# [172]	validation_0-error:0.129427
# [173]	validation_0-error:0.130071
# [174]	validation_0-error:0.130071
# [175]	validation_0-error:0.130715
# [176]	validation_0-error:0.130071
# [177]	validation_0-error:0.130071
# [178]	validation_0-error:0.129427
# [179]	validation_0-error:0.128139
# [180]	validation_0-error:0.128783
# [181]	validation_0-error:0.128783
# [182]	validation_0-error:0.128783
# [183]	validation_0-error:0.128783
# [184]	validation_0-error:0.128783
# [185]	validation_0-error:0.130071
# [186]	validation_0-error:0.129427
# [187]	validation_0-error:0.130071
# [188]	validation_0-error:0.127495
# [189]	validation_0-error:0.130071
# [190]	validation_0-error:0.131359
# [191]	validation_0-error:0.128783
# [192]	validation_0-error:0.131359
# [193]	validation_0-error:0.130715
# [194]	validation_0-error:0.130715
# [195]	validation_0-error:0.130715
# [196]	validation_0-error:0.130715
# [197]	validation_0-error:0.130715
# [198]	validation_0-error:0.130715
# [199]	validation_0-error:0.132646
# [200]	validation_0-error:0.13329
# [201]	validation_0-error:0.13329
# [202]	validation_0-error:0.132003
# [203]	validation_0-error:0.132646
# [204]	validation_0-error:0.132003
# [205]	validation_0-error:0.132646
# [206]	validation_0-error:0.132003
# [207]	validation_0-error:0.130715
# [208]	validation_0-error:0.130715
# [209]	validation_0-error:0.131359
# [210]	validation_0-error:0.132003
# [211]	validation_0-error:0.130715
# [212]	validation_0-error:0.132003
# [213]	validation_0-error:0.131359
# [214]	validation_0-error:0.128783
# [215]	validation_0-error:0.129427
# [216]	validation_0-error:0.130071
# [217]	validation_0-error:0.129427
# [218]	validation_0-error:0.129427
# [219]	validation_0-error:0.130071
# [220]	validation_0-error:0.128783
# [221]	validation_0-error:0.130071
# [222]	validation_0-error:0.130071
# [223]	validation_0-error:0.130071
# [224]	validation_0-error:0.130071
# [225]	validation_0-error:0.131359
# [226]	validation_0-error:0.130715
# [227]	validation_0-error:0.130715
# [228]	validation_0-error:0.130715
# [229]	validation_0-error:0.131359
# [230]	validation_0-error:0.130715
# [231]	validation_0-error:0.130071
# [232]	validation_0-error:0.129427
# [233]	validation_0-error:0.129427
# [234]	validation_0-error:0.129427
# [235]	validation_0-error:0.130071
# [236]	validation_0-error:0.129427
# [237]	validation_0-error:0.129427
# [238]	validation_0-error:0.128139
# [239]	validation_0-error:0.128783
# [240]	validation_0-error:0.130071
# [241]	validation_0-error:0.130715
# [242]	validation_0-error:0.132003
# [243]	validation_0-error:0.131359
# [244]	validation_0-error:0.131359
# [245]	validation_0-error:0.130715
# [246]	validation_0-error:0.130071
# [247]	validation_0-error:0.128783
# [248]	validation_0-error:0.130071
# [249]	validation_0-error:0.131359
# [250]	validation_0-error:0.130715
# [251]	validation_0-error:0.131359
# [252]	validation_0-error:0.130071
# [253]	validation_0-error:0.130715
# [254]	validation_0-error:0.130071
# [255]	validation_0-error:0.129427
# [256]	validation_0-error:0.130715
# [257]	validation_0-error:0.128139
# [258]	validation_0-error:0.130071
# [259]	validation_0-error:0.129427
# [260]	validation_0-error:0.128783
# [261]	validation_0-error:0.126851
# [262]	validation_0-error:0.127495
# [263]	validation_0-error:0.128139
# [264]	validation_0-error:0.127495
# [265]	validation_0-error:0.128139
# [266]	validation_0-error:0.127495
# [267]	validation_0-error:0.128139
# [268]	validation_0-error:0.128139
# [269]	validation_0-error:0.127495
# [270]	validation_0-error:0.126851
# [271]	validation_0-error:0.129427
# [272]	validation_0-error:0.130071
# [273]	validation_0-error:0.129427
# [274]	validation_0-error:0.130071
# [275]	validation_0-error:0.129427
# [276]	validation_0-error:0.130071
# [277]	validation_0-error:0.130715
# [278]	validation_0-error:0.130715
# [279]	validation_0-error:0.131359
# [280]	validation_0-error:0.130071
# [281]	validation_0-error:0.132003
# [282]	validation_0-error:0.13329
# [283]	validation_0-error:0.13329
# [284]	validation_0-error:0.132646
# [285]	validation_0-error:0.132003
# [286]	validation_0-error:0.132646
# [287]	validation_0-error:0.131359
# [288]	validation_0-error:0.131359
# [289]	validation_0-error:0.131359
# [290]	validation_0-error:0.132003
# [291]	validation_0-error:0.130715
# [292]	validation_0-error:0.129427
# [293]	validation_0-error:0.130715
# [294]	validation_0-error:0.131359
# [295]	validation_0-error:0.130071
# [296]	validation_0-error:0.130071
# [297]	validation_0-error:0.129427
# [298]	validation_0-error:0.130715
# [299]	validation_0-error:0.130715
# [300]	validation_0-error:0.130715
# [301]	validation_0-error:0.130715
# [302]	validation_0-error:0.130071
# [303]	validation_0-error:0.130715
# [304]	validation_0-error:0.130071
# [305]	validation_0-error:0.130071
# [306]	validation_0-error:0.131359
# [307]	validation_0-error:0.130071
# [308]	validation_0-error:0.130715
# [309]	validation_0-error:0.130071
# [310]	validation_0-error:0.130715
# [311]	validation_0-error:0.130071
# [312]	validation_0-error:0.130715
# [313]	validation_0-error:0.130071
# [314]	validation_0-error:0.130071
# [315]	validation_0-error:0.129427
# [316]	validation_0-error:0.129427
# [317]	validation_0-error:0.129427
# [318]	validation_0-error:0.129427
# [319]	validation_0-error:0.129427
# [320]	validation_0-error:0.130715
# [321]	validation_0-error:0.131359
# [322]	validation_0-error:0.130715
# [323]	validation_0-error:0.130715
# [324]	validation_0-error:0.132003
# [325]	validation_0-error:0.131359
# [326]	validation_0-error:0.132003
# [327]	validation_0-error:0.132003
# [328]	validation_0-error:0.131359
# [329]	validation_0-error:0.132646
# [330]	validation_0-error:0.132646
# [331]	validation_0-error:0.132003
# [332]	validation_0-error:0.130071
# [333]	validation_0-error:0.130715
# [334]	validation_0-error:0.130071
# [335]	validation_0-error:0.131359
# [336]	validation_0-error:0.130071
# [337]	validation_0-error:0.130071
# [338]	validation_0-error:0.130071
# [339]	validation_0-error:0.132003
# [340]	validation_0-error:0.132003
# [341]	validation_0-error:0.132646
# [342]	validation_0-error:0.132003
# [343]	validation_0-error:0.131359
# [344]	validation_0-error:0.135222
# [345]	validation_0-error:0.134578
# [346]	validation_0-error:0.134578
# [347]	validation_0-error:0.135222
# [348]	validation_0-error:0.135222
# [349]	validation_0-error:0.13329
# [350]	validation_0-error:0.13329
# [351]	validation_0-error:0.13329
# [352]	validation_0-error:0.133934
# [353]	validation_0-error:0.13651
# [354]	validation_0-error:0.135222
# [355]	validation_0-error:0.13651
# [356]	validation_0-error:0.135866
# [357]	validation_0-error:0.135866
# [358]	validation_0-error:0.134578
# [359]	validation_0-error:0.133934
# [360]	validation_0-error:0.134578
# [361]	validation_0-error:0.133934
# [362]	validation_0-error:0.134578
# [363]	validation_0-error:0.133934
# [364]	validation_0-error:0.13329
# [365]	validation_0-error:0.134578
# [366]	validation_0-error:0.133934
# [367]	validation_0-error:0.133934
# [368]	validation_0-error:0.133934
# [369]	validation_0-error:0.132646
# [370]	validation_0-error:0.132646
# [371]	validation_0-error:0.132646
# [372]	validation_0-error:0.132646
# [373]	validation_0-error:0.132003
# [374]	validation_0-error:0.13329
# [375]	validation_0-error:0.130715
# [376]	validation_0-error:0.131359
# [377]	validation_0-error:0.132003
# [378]	validation_0-error:0.131359
# [379]	validation_0-error:0.130715
# [380]	validation_0-error:0.130071
# [381]	validation_0-error:0.131359
# [382]	validation_0-error:0.132646
# [383]	validation_0-error:0.129427
# [384]	validation_0-error:0.130071
# [385]	validation_0-error:0.130071
# [386]	validation_0-error:0.130071
# [387]	validation_0-error:0.128783
# [388]	validation_0-error:0.129427
# [389]	validation_0-error:0.130071
# [390]	validation_0-error:0.130071
# [391]	validation_0-error:0.130071
# [392]	validation_0-error:0.130071
# [393]	validation_0-error:0.130715
# [394]	validation_0-error:0.130715
# [395]	validation_0-error:0.130071
# [396]	validation_0-error:0.130715
# [397]	validation_0-error:0.131359
# [398]	validation_0-error:0.130715
# [399]	validation_0-error:0.132003
# [400]	validation_0-error:0.130715
# [401]	validation_0-error:0.130715
# [402]	validation_0-error:0.132003
# [403]	validation_0-error:0.131359
# [404]	validation_0-error:0.130715
# [405]	validation_0-error:0.131359
# [406]	validation_0-error:0.132646
# [407]	validation_0-error:0.133934
# [408]	validation_0-error:0.13329
# [409]	validation_0-error:0.132646
# [410]	validation_0-error:0.13329
# [411]	validation_0-error:0.133934
# [412]	validation_0-error:0.13329
# [413]	validation_0-error:0.132003
# [414]	validation_0-error:0.132646
# [415]	validation_0-error:0.132646
# [416]	validation_0-error:0.131359
# [417]	validation_0-error:0.132003
# [418]	validation_0-error:0.132003
# [419]	validation_0-error:0.131359
# [420]	validation_0-error:0.131359
# [421]	validation_0-error:0.130715
# [422]	validation_0-error:0.131359
# [423]	validation_0-error:0.132003
# [424]	validation_0-error:0.13329
# [425]	validation_0-error:0.133934
# [426]	validation_0-error:0.134578
# [427]	validation_0-error:0.134578
# [428]	validation_0-error:0.134578
# [429]	validation_0-error:0.133934
# [430]	validation_0-error:0.133934
# [431]	validation_0-error:0.133934
# [432]	validation_0-error:0.135222
# [433]	validation_0-error:0.134578
# [434]	validation_0-error:0.135222
# [435]	validation_0-error:0.134578
# [436]	validation_0-error:0.13329
# [437]	validation_0-error:0.132646
# [438]	validation_0-error:0.132646
# [439]	validation_0-error:0.132003
# [440]	validation_0-error:0.132003
# [441]	validation_0-error:0.132003
# [442]	validation_0-error:0.131359
# [443]	validation_0-error:0.132003
# [444]	validation_0-error:0.130715
# [445]	validation_0-error:0.130715
# [446]	validation_0-error:0.131359
# [447]	validation_0-error:0.132646
# [448]	validation_0-error:0.132003
# [449]	validation_0-error:0.130715
# [450]	validation_0-error:0.131359
# [451]	validation_0-error:0.131359
# [452]	validation_0-error:0.131359
# [453]	validation_0-error:0.13329
# [454]	validation_0-error:0.132646
# [455]	validation_0-error:0.132646
# [456]	validation_0-error:0.131359
# [457]	validation_0-error:0.130715
# [458]	validation_0-error:0.131359
# [459]	validation_0-error:0.132003
# [460]	validation_0-error:0.131359
# [461]	validation_0-error:0.130715
# [462]	validation_0-error:0.130715
# [463]	validation_0-error:0.131359
# [464]	validation_0-error:0.132003
# [465]	validation_0-error:0.132003
# [466]	validation_0-error:0.132003
# [467]	validation_0-error:0.130071
# [468]	validation_0-error:0.130715
# [469]	validation_0-error:0.131359
# [470]	validation_0-error:0.131359
# [471]	validation_0-error:0.132003
# [472]	validation_0-error:0.131359
# [473]	validation_0-error:0.132003
# [474]	validation_0-error:0.132003
# [475]	validation_0-error:0.131359
# [476]	validation_0-error:0.131359
# [477]	validation_0-error:0.132003
# [478]	validation_0-error:0.132003
# [479]	validation_0-error:0.132003
# [480]	validation_0-error:0.132646
# [481]	validation_0-error:0.132003
# [482]	validation_0-error:0.131359
# [483]	validation_0-error:0.131359
# [484]	validation_0-error:0.131359
# [485]	validation_0-error:0.132003
# [486]	validation_0-error:0.130071
# [487]	validation_0-error:0.129427
# [488]	validation_0-error:0.128783
# [489]	validation_0-error:0.128783
# [490]	validation_0-error:0.128139
# [491]	validation_0-error:0.128783
# [492]	validation_0-error:0.128139
# [493]	validation_0-error:0.128783
# [494]	validation_0-error:0.127495
# [495]	validation_0-error:0.128783
# [496]	validation_0-error:0.128783
# [497]	validation_0-error:0.128783
# [498]	validation_0-error:0.127495
# [499]	validation_0-error:0.128139

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Classification report

# %%
print('CBOW: \n', cbow_report)
print('-'*55)
print('Skip-gram: \n', skipgram_report)
# Out:
# CBOW:
#                precision    recall  f1-score   support
#
#            0       0.78      0.78      0.78       489
#            1       0.90      0.90      0.90      1064
#
#     accuracy                           0.86      1553
#    macro avg       0.84      0.84      0.84      1553
# weighted avg       0.86      0.86      0.86      1553
#
# -------------------------------------------------------
# Skip-gram:
#                precision    recall  f1-score   support
#
#            0       0.80      0.79      0.79       489
#            1       0.90      0.91      0.91      1064
#
#     accuracy                           0.87      1553
#    macro avg       0.85      0.85      0.85      1553
# weighted avg       0.87      0.87      0.87      1553

# %% [markdown]
# ## Confusion matrix

# %%
print('CBOW: \n')
display(cbow_cnfm)
print('-'*26)

print('Skip-gram: \n')
display(skipgram_cnfm)
# Out:
# CBOW:
#           Pred_0  Pred_1
# Actual_0     379     110
# Actual_1     109     955
# --------------------------
# Skip-gram:
#           Pred_0  Pred_1
# Actual_0     385     104
# Actual_1      95     969
